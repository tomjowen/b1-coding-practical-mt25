# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/home/codespace/.python/current/lib/python312.zip', '/home/codespace/.python/current/lib/python3.12', '/home/codespace/.python/current/lib/python3.12/lib-dynload', '', '/workspaces/b1-coding-practical-mt25/.venv/lib/python3.12/site-packages']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules

import sys
sys.path.append('/workspaces/b1-coding-practical-mt25')

from uuv_mission.dynamic import Submarine, ClosedLoop, Mission
from uuv_mission.control import Control

sub = Submarine()
controller = Control()

# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("/workspaces/b1-coding-practical-mt25/data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#      12 # Instantiate your controller (depending on your implementation)
#      13 closed_loop = ClosedLoop(sub, controller)
# ---> 14 mission = Mission.from_csv("/data/mission.csv") # You must implement this method in the Mission class
#      16 trajectory = closed_loop.simulate_with_random_disturbances(mission)
#      17 trajectory.plot_completed_mission(mission)
#
# File /workspaces/b1-coding-practical-mt25/uuv_mission/dynamic.py:80, in Mission.from_csv(cls, file_name)
#      77 @classmethod
#      78 def from_csv(cls, file_name: str):
#      79     # Read csv file and parse data to local variables
# ---> 80     reference = np.loadtxt(file_name, delimiter=',', usecols=0)
#      81     cave_height = np.loadtxt(file_name, delimiter=',', usecols=1)
#      82     cave_depth = np.loadtxt(file_name, delimiter=',', usecols=2)
#
# File /workspaces/b1-coding-practical-mt25/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File /workspaces/b1-coding-practical-mt25/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1024, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1022     fname = os.fspath(fname)
#    1023 if isinstance(fname, str):
# -> 1024     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1025     if encoding is None:
#    1026         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /workspaces/b1-coding-practical-mt25/.venv/lib/python3.12/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /workspaces/b1-coding-practical-mt25/.venv/lib/python3.12/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /data/mission.csv not found.
